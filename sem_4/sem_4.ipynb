# %% [markdown]
# ### Деревья решений

# %%
import pandas as pd

# %%
columns = [
'Sex',
'Length',
'Diameter',
'Height',
'Whole weight',
'Shucked weight',
'Viscera weight',
'Shell weight',
'Rings'    
]

'''Rings / integer / -- / +1.5 gives the age in years '''
# Out:
# 'Rings / integer / -- / +1.5 gives the age in years '

# %%
data = pd.read_table('abalone.data', sep=',', header=None)
data.columns = columns
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# закодировать категориальную переменную

# %%
data = pd.concat([pd.get_dummies(data['Sex']), data], axis=1).copy()
data.drop('Sex', inplace=True, axis=1)
data
# Out:
#         F    I    M  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     0.0  0.0  1.0   0.455     0.365   0.095        0.5140          0.2245
# 1     0.0  0.0  1.0   0.350     0.265   0.090        0.2255          0.0995
# 2     1.0  0.0  0.0   0.530     0.420   0.135        0.6770          0.2565
# 3     0.0  0.0  1.0   0.440     0.365   0.125        0.5160          0.2155
# 4     0.0  1.0  0.0   0.330     0.255   0.080        0.2050          0.0895
# 5     0.0  1.0  0.0   0.425     0.300   0.095        0.3515          0.1410
# 6     1.0  0.0  0.0   0.530     0.415   0.150        0.7775          0.2370
# 7     1.0  0.0  0.0   0.545     0.425   0.125        0.7680          0.2940
# 8     0.0  0.0  1.0   0.475     0.370   0.125        0.5095          0.2165
# 9     1.0  0.0  0.0   0.550     0.440   0.150        0.8945          0.3145
# 10    1.0  0.0  0.0   0.525     0.380   0.140        0.6065          0.1940
# 11    0.0  0.0  1.0   0.430     0.350   0.110        0.4060          0.1675
# 12    0.0  0.0  1.0   0.490     0.380   0.135        0.5415          0.2175
# 13    1.0  0.0  0.0   0.535     0.405   0.145        0.6845          0.2725
# 14    1.0  0.0  0.0   0.470     0.355   0.100        0.4755          0.1675
# 15    0.0  0.0  1.0   0.500     0.400   0.130        0.6645          0.2580
# 16    0.0  1.0  0.0   0.355     0.280   0.085        0.2905          0.0950
# 17    1.0  0.0  0.0   0.440     0.340   0.100        0.4510          0.1880
# 18    0.0  0.0  1.0   0.365     0.295   0.080        0.2555          0.0970
# 19    0.0  0.0  1.0   0.450     0.320   0.100        0.3810          0.1705
# 20    0.0  0.0  1.0   0.355     0.280   0.095        0.2455          0.0955
# 21    0.0  1.0  0.0   0.380     0.275   0.100        0.2255          0.0800
# 22    1.0  0.0  0.0   0.565     0.440   0.155        0.9395          0.4275
# 23    1.0  0.0  0.0   0.550     0.415   0.135        0.7635          0.3180
# 24    1.0  0.0  0.0   0.615     0.480   0.165        1.1615          0.5130
# 25    1.0  0.0  0.0   0.560     0.440   0.140        0.9285          0.3825
# 26    1.0  0.0  0.0   0.580     0.450   0.185        0.9955          0.3945
# 27    0.0  0.0  1.0   0.590     0.445   0.140        0.9310          0.3560
# 28    0.0  0.0  1.0   0.605     0.475   0.180        0.9365          0.3940
# 29    0.0  0.0  1.0   0.575     0.425   0.140        0.8635          0.3930
# ...   ...  ...  ...     ...       ...     ...           ...             ...
# 4147  0.0  0.0  1.0   0.695     0.550   0.195        1.6645          0.7270
# 4148  0.0  0.0  1.0   0.770     0.605   0.175        2.0505          0.8005
# 4149  0.0  1.0  0.0   0.280     0.215   0.070        0.1240          0.0630
# 4150  0.0  1.0  0.0   0.330     0.230   0.080        0.1400          0.0565
# 4151  0.0  1.0  0.0   0.350     0.250   0.075        0.1695          0.0835
# 4152  0.0  1.0  0.0   0.370     0.280   0.090        0.2180          0.0995
# 4153  0.0  1.0  0.0   0.430     0.315   0.115        0.3840          0.1885
# 4154  0.0  1.0  0.0   0.435     0.330   0.095        0.3930          0.2190
# 4155  0.0  1.0  0.0   0.440     0.350   0.110        0.3805          0.1575
# 4156  0.0  0.0  1.0   0.475     0.370   0.110        0.4895          0.2185
# 4157  0.0  0.0  1.0   0.475     0.360   0.140        0.5135          0.2410
# 4158  0.0  1.0  0.0   0.480     0.355   0.110        0.4495          0.2010
# 4159  1.0  0.0  0.0   0.560     0.440   0.135        0.8025          0.3500
# 4160  1.0  0.0  0.0   0.585     0.475   0.165        1.0530          0.4580
# 4161  1.0  0.0  0.0   0.585     0.455   0.170        0.9945          0.4255
# 4162  0.0  0.0  1.0   0.385     0.255   0.100        0.3175          0.1370
# 4163  0.0  1.0  0.0   0.390     0.310   0.085        0.3440          0.1810
# 4164  0.0  1.0  0.0   0.390     0.290   0.100        0.2845          0.1255
# 4165  0.0  1.0  0.0   0.405     0.300   0.085        0.3035          0.1500
# 4166  0.0  1.0  0.0   0.475     0.365   0.115        0.4990          0.2320
# 4167  0.0  0.0  1.0   0.500     0.380   0.125        0.5770          0.2690
# 4168  1.0  0.0  0.0   0.515     0.400   0.125        0.6150          0.2865
# 4169  0.0  0.0  1.0   0.520     0.385   0.165        0.7910          0.3750
# 4170  0.0  0.0  1.0   0.550     0.430   0.130        0.8395          0.3155
# 4171  0.0  0.0  1.0   0.560     0.430   0.155        0.8675          0.4000
# 4172  1.0  0.0  0.0   0.565     0.450   0.165        0.8870          0.3700
# 4173  0.0  0.0  1.0   0.590     0.440   0.135        0.9660          0.4390
# 4174  0.0  0.0  1.0   0.600     0.475   0.205        1.1760          0.5255
# 4175  1.0  0.0  0.0   0.625     0.485   0.150        1.0945          0.5310
# 4176  0.0  0.0  1.0   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# 5             0.0775        0.1200      8
# 6             0.1415        0.3300     20
# 7             0.1495        0.2600     16
# 8             0.1125        0.1650      9
# 9             0.1510        0.3200     19
# 10            0.1475        0.2100     14
# 11            0.0810        0.1350     10
# 12            0.0950        0.1900     11
# 13            0.1710        0.2050     10
# 14            0.0805        0.1850     10
# 15            0.1330        0.2400     12
# 16            0.0395        0.1150      7
# 17            0.0870        0.1300     10
# 18            0.0430        0.1000      7
# 19            0.0750        0.1150      9
# 20            0.0620        0.0750     11
# 21            0.0490        0.0850     10
# 22            0.2140        0.2700     12
# 23            0.2100        0.2000      9
# 24            0.3010        0.3050     10
# 25            0.1880        0.3000     11
# 26            0.2720        0.2850     11
# 27            0.2340        0.2800     12
# 28            0.2190        0.2950     15
# 29            0.2270        0.2000     11
# ...              ...           ...    ...
# 4147          0.3600        0.4450     11
# 4148          0.5260        0.3550     11
# 4149          0.0215        0.0300      6
# 4150          0.0365        0.0460      7
# 4151          0.0355        0.0410      6
# 4152          0.0545        0.0615      7
# 4153          0.0715        0.1100      8
# 4154          0.0750        0.0885      6
# 4155          0.0895        0.1150      6
# 4156          0.1070        0.1460      8
# 4157          0.1045        0.1550      8
# 4158          0.0890        0.1400      8
# 4159          0.1615        0.2590      9
# 4160          0.2170        0.3000     11
# 4161          0.2630        0.2845     11
# 4162          0.0680        0.0920      8
# 4163          0.0695        0.0790      7
# 4164          0.0635        0.0810      7
# 4165          0.0505        0.0880      7
# 4166          0.0885        0.1560     10
# 4167          0.1265        0.1535      9
# 4168          0.1230        0.1765      8
# 4169          0.1800        0.1815     10
# 4170          0.1955        0.2405     10
# 4171          0.1720        0.2290      8
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 11 columns]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()

# %%
columns = data.columns
X = data[columns[:-1]]
Y = data[columns[-1]]

# %% [markdown]
# Обучить дерево с различными параметрами глубины. Построить график точность/глубина.

# %%
clf.fit(X,Y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
clf.score(X,Y)
# Out:
# 1.0

# %%
from sklearn.model_selection

# %%
from sklearn.cross_validation import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y)

# %%
clf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
clf.score(X_test, Y_test)
# Out:
# 0.75119617224880386

# %%
def my_depth(d):
    cfl = DecisionTreeClassifier(max_depth=d)
    clf.fit(X_train,Y_train)
    print(
    clf.score(X_train, Y_train),
    clf.score(X_test, Y_test))

# %%
my_depth(10)
# Out:
# 1.0 0.756937799043

# %%
data['Rings']
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6        True
# 7        True
# 8       False
# 9        True
# 10       True
# 11      False
# 12      False
# 13      False
# 14      False
# 15       True
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22       True
# 23      False
# 24      False
# 25      False
# 26      False
# 27       True
# 28       True
# 29      False
#         ...
# 4147    False
# 4148    False
# 4149    False
# 4150    False
# 4151    False
# 4152    False
# 4153    False
# 4154    False
# 4155    False
# 4156    False
# 4157    False
# 4158    False
# 4159    False
# 4160    False
# 4161    False
# 4162    False
# 4163    False
# 4164    False
# 4165    False
# 4166    False
# 4167    False
# 4168    False
# 4169    False
# 4170    False
# 4171    False
# 4172    False
# 4173    False
# 4174    False
# 4175    False
# 4176     True
# Name: Rings, dtype: bool

# %%
data['Rings'] = data['Rings'].apply(lambda x: x>11)

# %%
# %matplotlib inline
data['Rings'].hist()

# %%
for i in range(2, 10):
    print('depth {}'.format(i))
    my_depth(i)
# Out:
# depth 2
# 1.0 0.755023923445
# depth 3
# 1.0 0.751196172249
# depth 4
# 1.0 0.749282296651
# depth 5
# 1.0 0.756937799043
# depth 6
# 1.0 0.745454545455
# depth 7
# 1.0 0.749282296651
# depth 8
# 1.0 0.746411483254
# depth 9
# 1.0 0.748325358852

# %%
X_test
# Out:
#         F    I    M  Length  Diameter  Height  Whole weight  Shucked weight  \
# 1020  0.0  0.0  1.0   0.635     0.525   0.185        1.4065          0.6840
# 1994  0.0  1.0  0.0   0.290     0.210   0.065        0.0970          0.0375
# 1418  0.0  0.0  1.0   0.705     0.555   0.215        2.1410          1.0465
# 1078  0.0  1.0  0.0   0.420     0.310   0.095        0.2790          0.1255
# 1294  0.0  1.0  0.0   0.520     0.395   0.125        0.6630          0.3005
# 3963  0.0  1.0  0.0   0.270     0.205   0.075        0.1180          0.0590
# 637   0.0  0.0  1.0   0.355     0.260   0.085        0.1905          0.0810
# 3875  0.0  0.0  1.0   0.295     0.225   0.090        0.1385          0.0480
# 303   0.0  0.0  1.0   0.360     0.270   0.100        0.2170          0.0885
# 2110  0.0  1.0  0.0   0.325     0.250   0.055        0.1660          0.0760
# 535   0.0  1.0  0.0   0.465     0.380   0.130        0.4540          0.1895
# 823   0.0  1.0  0.0   0.385     0.290   0.095        0.3120          0.1430
# 3407  0.0  1.0  0.0   0.350     0.265   0.080        0.1920          0.0810
# 3266  1.0  0.0  0.0   0.495     0.385   0.135        0.6625          0.3005
# 2821  0.0  1.0  0.0   0.390     0.290   0.090        0.2625          0.1170
# 2328  1.0  0.0  0.0   0.525     0.425   0.145        0.7995          0.3345
# 544   1.0  0.0  0.0   0.380     0.290   0.105        0.2570          0.0990
# 1502  0.0  0.0  1.0   0.630     0.480   0.150        1.2710          0.6605
#
#       Viscera weight  Shell weight
# 1020          0.3000        0.3745
# 1994          0.0220        0.0300
# 1418          0.3830        0.5280
# 1078          0.0510        0.0880
# 1294          0.1310        0.1905
# 3963          0.0310        0.0305
# 637           0.0485        0.0550
# 3875          0.0460        0.0500
# 303           0.0495        0.0715
# 2110          0.0510        0.0450
# 535           0.0800        0.1550
# 823           0.0635        0.0860
# 3407          0.0465        0.0530
# 3266          0.1635        0.1850
# 2855          0.3460        0.3850
# 3735          0.2325        0.2830
# 646           0.0265        0.0350
# 2027          0.2120        0.2475
# 251           0.2805        0.3600
# 794           0.2600        0.3635
# 3654          0.1855        0.2080
# 3224          0.3075        0.4700
# 1097          0.1085        0.1665
# 237           0.0030        0.0040
# 1316          0.1560        0.2550
# 1649          0.2680        0.2650
# 2750          0.1400        0.1805
# 2481          0.0600        0.0800
# 3738          0.3220        0.3550
# 406           0.1045        0.1500
# ...              ...           ...
# 1730          0.2530        0.3665
# 1479          0.2465        0.2385
# 2716          0.0380        0.0530
# 3420          0.2140        0.3700
# 1793          0.2245        0.2485
# 3003          0.2965        0.3260
# 2338          0.3580        0.4850
# 570           0.1090        0.1275
# 2074          0.2115        0.3560
# 3847          0.0870        0.1590
# 3463          0.2930        0.4750
# 1952          0.2505        0.2925
# 3650          0.1405        0.1710
# 1708          0.3715        0.3845
# 3381          0.2665        0.3250
# 14            0.0805        0.1850
# 2309          0.1640        0.1950
# 4113          0.2140        0.2000
# 3967          0.0400        0.0450
# 2226          0.0525        0.0800
# 903           0.0375        0.0425
# 2047          0.0650        0.0870
# 3693          0.2305        0.3990
# 2897          0.1580        0.2080
# 3619          0.2645        0.3200
# 3397          0.1215        0.1945
# 2821          0.0540        0.0770
# 2328          0.2090        0.2400
# 544           0.0510        0.0850
# 1502          0.2425        0.3100
#
# [1045 rows x 10 columns]

# %%
Y_test
# Out:
# 1020    10
# 1994     6
# 1418    11
# 1078     6
# 1294     9
# 3963     4
# 637      6
# 3875     9
# 303      6
# 2110     5
# 535     11
# 823      6
# 3407     6
# 3266    11
# 2855    11
# 3735     9
# 646      6
# 2027     9
# 251     13
# 794     12
# 3654     9
# 3224    16
# 1097     8
# 237      3
# 1316     9
# 1649    10
# 2750     8
# 2481     8
# 3738     9
# 406      8
#         ..
# 1730    11
# 1479     8
# 2716     6
# 3420    10
# 1793    10
# 3003    10
# 2338    17
# 570     16
# 2074    11
# 3847     9
# 3463    11
# 1952    10
# 3650     8
# 1708    14
# 3381    19
# 14      10
# 2309    13
# 4113     8
# 3967     6
# 2226     7
# 903      6
# 2047     6
# 3693    11
# 2897    10
# 3619    12
# 3397    12
# 2821     7
# 2328    15
# 544     10
# 1502    11
# Name: Rings, dtype: int64

# %%
import sklearn

# %%
from sklearn.model_selection import GridSearchCV
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-620574e2b43b> in <module>()
# ----> 1 from sklearn.model_selection import GridSearchCV
#
# ImportError: No module named 'sklearn.model_selection'

# %% [markdown]
# Провести кросс валидацию
